# %%
# notebooks/Eda.ipynb
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load data
df = pd.read_csv("../data/processed/engineered_nepal_dataset.csv")
print(df.describe())
# Out:
#                S.N.  Winter_Trend  PreMonsoon_Trend  Monsoon_Trend  \
# count  7.500000e+01  7.500000e+01      7.500000e+01   7.500000e+01
# mean   1.480297e-17 -1.924387e-17      1.036208e-17   5.921189e-18
# std    1.006734e+00  1.006734e+00      1.006734e+00   1.006734e+00
# min   -1.709109e+00 -2.780185e+00     -1.917769e+00  -2.200638e+00
# 25%   -8.545544e-01 -6.980653e-01     -7.049340e-01  -5.742683e-01
# 50%    0.000000e+00 -9.902418e-02     -7.182862e-02  -5.226107e-02
# 75%    8.545544e-01  6.181943e-01      6.994631e-01   5.572503e-01
# max    1.709109e+00  2.578323e+00      2.484547e+00   2.817270e+00
#
#        PostMonsoon_Trend  Glaciers Number  Glaciers Area (sq. km)  \
# count       7.500000e+01     7.500000e+01            7.500000e+01
# mean       -1.065814e-16     5.625130e-17           -1.250851e-16
# std         1.006734e+00     1.006734e+00            1.006734e+00
# min        -3.235340e+00    -2.699040e+00           -2.916354e+00
# 25%        -5.940899e-01    -7.581525e-01           -4.432794e-01
# 50%         9.493189e-02     6.526245e-01           -2.259856e-01
# 75%         7.648142e-01     9.917810e-01            1.300503e+00
# max         1.855765e+00     9.917810e-01            1.300503e+00
#
#        Glacial Lakes Number  Glacier_Lake_Ratio  Total_Trend_Magnitude  \
# count          7.500000e+01        7.500000e+01              75.000000
# mean          -5.181041e-17       -6.365279e-17               2.305943
# std            1.006734e+00        1.006734e+00               1.442316
# min           -1.710064e+00       -4.736322e-01               0.429722
# 25%           -1.313518e+00       -4.736322e-01               1.299455
# 50%            4.764976e-01       -4.322825e-01               1.909950
# 75%            1.006461e+00        3.136470e-01               3.002744
# max            1.006461e+00        3.963633e+00               6.449528
#
#        High_Monsoon_Trend
# count           75.000000
# mean             0.493333
# std              0.503322
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              1.000000
# max              1.000000

# %% [markdown]
# # Correlation heatmap

# %%
plt.figure(figsize=(10, 8))

# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=['float64', 'int64'])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Distribution of Monsoon Trend

# %%
sns.histplot(df['Monsoon_Trend'], kde=True)
plt.title("Distribution of Monsoon Trend")
plt.show()
